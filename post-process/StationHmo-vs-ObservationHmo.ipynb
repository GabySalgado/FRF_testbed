# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 


all_poss=['o', '*', 'd', 'X', '^'] # marker style for 8m-array, AWAC-6m, xp200m, xp150m & xp125m


x = np.arange(0,5,1)
y = np.arange(0,5,1)


# 2015-10-05-00
FRF_obs = [3.33,3.73,1.62,1.37,1.24] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
FRF2D_0cd = [3.19,3.0869,1.7542,1.6234,1.5536]
FRF1D_0cd = [3.2202,3.2129,2.0402,1.8842,1.8367]
FRF1D_01cd = [2.9243,2.8608,1.8414,1.7322,1.7201]
FRF1D_02cd = [2.8757,2.7458,1.7594,1.6498,1.6388]


fit_2D_0cd = np.polyfit(FRF_obs,FRF2D_0cd,1)
fit_fn_2D_0cd = np.poly1d(fit_2D_0cd) 

fit_1D_0cd = np.polyfit(FRF_obs,FRF1D_0cd,1)
fit_fn_1D_0cd = np.poly1d(fit_1D_0cd) 

# fit_fn is now a function which takes in x and returns an estimate for y
fig = plt.figure(figsize=(8,8))


for i in range(len(FRF_obs)):
    plt.plot(FRF_obs[i],FRF2D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='orange', markersize=10)
    plt.plot(FRF_obs[i],FRF1D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='red', markersize=10)
    plt.plot(FRF_obs[i],FRF1D_01cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='green', markersize=10)
    plt.plot(FRF_obs[i],FRF1D_02cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='blue', markersize=10)
plt.plot(x,y,'k--')

plt.xlabel('FRF Observed Wave Heights [m]')
plt.ylabel('FUNWAVE Wave Heights [m]')

plt.grid(linestyle='--', linewidth=0.5)

plt.legend(['FRF2D_0cd','FRF1D_0cd','FRF1D_01cd','FRF1D_02cd'])
plt.title('FRF 2015-10-05-00')
# Out:
# Text(0.5,1,'FRF 2015-10-05-00')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 


all_poss=['o', '*', 'd', 'X', '^'] # omarker style for 8m-array, AWAC-6m, xp200m, xp150m & xp125m


x = np.arange(0,5,1)
y = np.arange(0,5,1)

### DATES:

# 2015-10-05-00
#FRF_obs = [3.33,3.73,1.62,1.37,1.24] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
#FRF2D_0cd = [3.19,3.0869,1.7542,1.6234,1.5536]
#FRF1D_0cd = [3.2202,3.2129,2.0402,1.8842,1.8367]
#FRF1D_0cd_Oct1 = [3.2269,3.2166,1.9916,1.8627,1.6451]
#FRF2D_0cd_Oct1 = [2.6363,2.9602,1.7369,1.5371,1.4597]

# 2015-10-05-01
#FRF_obs = [3.59,3.88,1.54,1.35,1.23] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
#FRF2D_0cd = [3.4028,3.3484,1.8407,1.7436,1.5728]
#FRF1D_0cd = [3.5131,3.4624,2.0665,1.9163,1.8467]
#FRF1D_0cd_Oct1 = [3.5352,3.478,2.0078,1.9166,1.7057]
#FRF2D_0cd_Oct1 = [2.9166,3.2438,1.7244,1.5428,1.5072]

# 2015-10-05-12
#FRF_obs = [3.29,3.37,1.53,1.38,1.25] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
#FRF2D_0cd = [3.1151,3.0933,1.7501,1.6381,1.5067]
#FRF1D_0cd = [3.2604,2.2519,1.9279,1.7957,1.7425]
#FRF1D_0cd_Oct1 = [3.2289,3.2303,1.898,1.7552,1.599]
#FRF2D_0cd_Oct1 = [2.6427,3.0334,1.6486,1.4282,1.4033]

# 2015-10-05-23
#FRF_obs = [2.96,2.91,1.56,1.43,1.26] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
#FRF2D_0cd = [2.8774,2.8573,1.8827,1.6862,1.6103]
#FRF1D_0cd = [2.9477,2.9893,1.948,1.7988,1.842]
#FRF1D_0cd_Oct1 = [2.9236,2.9357,1.9054,1.7755,1.6611]
#FRF2D_0cd_Oct1 = [2.5565,2.8566,1.7242,1.5963,1.4854]

# 2015-10-06-12
#FRF_obs = [2.82,2.77,1.44,1.41,1.52] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
#FRF2D_0cd = [2.7314,2.821,1.752,1.5972,1.4795]
#FRF1D_0cd = [2.8267,2.8599,1.8333,1.6495,1.699]
#FRF1D_0cd_Oct1 = [2.7755,2.8123,1.7989,1.6446,1.5529]
#FRF2D_0cd_Oct1 = [2.4712,2.7275,1.5633,1.4377,1.376]

# 2015-10-06-23
FRF_obs = [2.2,2.64,1.52,1.45,1.39] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
FRF2D_0cd = [2.1055,2.2238,1.6284,1.4155,1.3966]
FRF1D_0cd = [2.1944,2.2754,1.7434,1.6248,1.7152]
FRF1D_0cd_Oct1 = [2.2119,2.2577,1.7169,1.5919,1.5652]
FRF2D_0cd_Oct1 = [2.0107,2.1379,1.602,1.4851,1.3886]

fig = plt.figure(figsize=(8.0,8.0))
axes = fig.add_subplot(1, 1, 1)


for i in range(len(FRF_obs)):
    axes.plot(FRF_obs[i],FRF2D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='orange', markersize=10)
    axes.plot(FRF_obs[i],FRF1D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='red', markersize=10)
    axes.plot(FRF_obs[i],FRF1D_0cd_Oct1[i],marker=all_poss[i],linestyle='None', markerfacecolor='green', markersize=10)
    axes.plot(FRF_obs[i],FRF2D_0cd_Oct1[i],marker=all_poss[i],linestyle='None', markerfacecolor='blue', markersize=10)
axes.plot(x,y,'k--')

plt.xlabel('FRF Observed Wave Heights [m]')
plt.ylabel('FUNWAVE Model Wave Heights [m]')

plt.grid(linestyle='--', linewidth=0.5)

legend1 = axes.legend(['FRF2D_0cd_Oct8thBathy','FRF1D_0cd_Oct8thBathy','FRF1D_0cd_Oct1rstBathy','FRF2D_0cd_Oct1rstBathy'])
legend2 = axes.legend(all_poss, ['8m-array','6m-awac','xp200m','xp150m','xp125m'], loc=4)
axes.add_artist(legend1)



plt.title('FRF 2015-10-06-23')
plt.savefig('2015100623_Oct8thBathy-vs-Oct1rstBathy.png', dpi=300)
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/legend.py:937: UserWarning: Legend does not support 'o' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   "aka-proxy-artists".format(orig_handle)
# /anaconda3/lib/python3.7/site-packages/matplotlib/legend.py:937: UserWarning: Legend does not support '*' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   "aka-proxy-artists".format(orig_handle)
# /anaconda3/lib/python3.7/site-packages/matplotlib/legend.py:937: UserWarning: Legend does not support 'd' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   "aka-proxy-artists".format(orig_handle)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 


all_poss=['o', '*', 'd', 'X', '^'] # omarker style for 8m-array, AWAC-6m, xp200m, xp150m & xp125m


x = np.arange(0,5,1)
y = np.arange(0,5,1)


# 2015-10-05-00
FRF_obs = [3.33,3.73,1.62,1.37,1.24] # observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
FRF2D_0cd = [3.19,3.0869,1.7542,1.6234,1.5536]
FRF1D_0cd = [3.2202,3.2129,2.0402,1.8842,1.8367]
FRF1D_01cd = [2.9243,2.8608,1.8414,1.7322,1.7201]
FRF1D_02cd = [2.8757,2.7458,1.7594,1.6498,1.6388]

# 2015-10-05-01
FRF_obs_10_05_01 = [3.59,3.88,1.54,1.35,1.23]# observations at FRF (8m-array, AWAC-6m, xp200m, xp150m & xp125m)
FRF2D_0cd_10_05_01 = [3.4028,3.3484,1.8407,1.7436,1.5728]
FRF1D_0cd_10_05_01 = [3.5131,3.4624,2.0665,1.9163,1.8467]
FRF1D_01cd_10_05_01 = [3.4884,3.3566,1.9696,1.8383,1.7136]
FRF1D_02cd_10_05_01 = [3.4508,3.2271,1.868,1.755,1.6405]


fit_2D_0cd = np.polyfit(FRF_obs,FRF2D_0cd,1)
fit_fn_2D_0cd = np.poly1d(fit_2D_0cd) 

fit_1D_0cd = np.polyfit(FRF_obs,FRF1D_0cd,1)
fit_fn_1D_0cd = np.poly1d(fit_1D_0cd) 

# fit_fn is now a function which takes in x and returns an estimate for y
fig = plt.figure(figsize=(8,8))


for i in range(len(FRF_obs)):
    plt.plot(FRF_obs[i],FRF2D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='orange',
             markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs[i],FRF1D_0cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='red',
             markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs[i],FRF1D_01cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='green',
             markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs[i],FRF1D_02cd[i],marker=all_poss[i],linestyle='None', markerfacecolor='blue',
             markeredgecolor=None, markersize=10)
    
    plt.plot(FRF_obs_10_05_01[i],FRF2D_0cd_10_05_01[i],marker=all_poss[i],linestyle='None',
             markerfacecolor='c', markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs_10_05_01[i],FRF1D_0cd_10_05_01[i],marker=all_poss[i],linestyle='None',
             markerfacecolor='y', markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs_10_05_01[i],FRF1D_01cd_10_05_01[i],marker=all_poss[i],linestyle='None',
             markerfacecolor='magenta', markeredgecolor=None, markersize=10)
    plt.plot(FRF_obs_10_05_01[i],FRF1D_02cd_10_05_01[i],marker=all_poss[i],linestyle='None',
             markerfacecolor='lime', markeredgecolor=None, markersize=10)
    
plt.plot(x,y,'k--')

plt.xlabel('FRF Observed Wave Heights [m]')
plt.ylabel('FUNWAVE Wave Heights [m]')

plt.grid(linestyle='--', linewidth=0.5)

plt.legend(['FRF2D_0cd_2015-10-05-00','FRF1D_0cd_2015-10-05-00','FRF1D_01cd_2015-10-05-00','FRF1D_02cd_2015-10-05-00',
           'FRF2D_0cd_2015-10-05-01','FRF1D_0cd_2015-10-05-01','FRF1D_01cd_2015-10-05-01','FRF1D_02cd_2015-10-05-01'])
